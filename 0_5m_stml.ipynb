# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/Urban Air Quality and Health Impact Dataset.csv',usecols=(['cloudcover','visibility']))
data.head()
#print(data)
data.shape
#data.info()
data.describe()
data.skew()
data.kurt()
# Out:
# cloudcover    1.394269
# visibility   -0.666395
# dtype: float64

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()
sns.pairplot(data)
plt.show()
plt.plot(data, color='r')
plt.show()
x=data.drop('visibility',axis=1)
y=data.visibility
from sklearn import linear_model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 1)
# (200, 1)
# (800,)
# (200,)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
reg.intercept_
reg.coef_
y_pred=reg.predict(x_test)
y_pred
y_test
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error: 1.8897405632864497
# Mean Squared Error: 4.599088148208928
